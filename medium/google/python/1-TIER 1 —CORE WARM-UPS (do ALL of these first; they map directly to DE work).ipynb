# %%
def two_sum(nums, target):
    for i in range(len(nums)-1):
        for j in range(i + 1, len(nums)):
            if nums[i] + nums[j] == target:
                return [i, j]

    return []


# input
nums = [2, 7, 11, 15]
target = 9

# function call
result = two_sum(nums, target)

# output
print(result)
# Out:
# [0, 1]

# %%
# Time complexity: O(n²)
# Space complexity: O(1)

# %%
def two_sum(nums, target):
    lookup = {}

    for i in range(len(nums)):
        print(lookup)
        num = nums[i]
        needed = target - num

        if needed in lookup:
            return [lookup[needed], i]

        lookup[num] = i

    return []


# input
nums = [1, 2, 11, 15,7]
target = 9

# function call
result = two_sum(nums, target)

# output
print(result)
# Out:
# {}
# {1: 0}
# {1: 0, 2: 1}
# {1: 0, 2: 1, 11: 2}
# {1: 0, 2: 1, 11: 2, 15: 3}
# [1, 4]

# %%
def two_sum(nums, target):
    lookup = {}

    for i, num in enumerate(nums):
        needed = target - num

        if needed in lookup:
            return [lookup[needed], i]

        lookup[num] = i

    return []


nums = [2, 7, 11, 15]
target = 9

print(two_sum(nums, target))
# Out:
# [0, 1]

# %%
nums = [1, 2, 3, 1]

# %%
def duplicate_check(nums):
    counter={}
    for i in range(len(nums)):
        if nums[i] in counter:
            counter[nums[i]]+=1
        else:
             counter[nums[i]]=1
    print(counter)     
    for k in counter.values():
        if k>1:
            return True
    return False
print(duplicate_check(nums))
# Out:
# {1: 2, 2: 1, 3: 1}
# True

# %%
nums = []
print(duplicate_check(nums))
# Out:
# {}
# False

# %%
def contains_duplicate(nums):
    for i in range(len(nums)):
        for j in range(i + 1, len(nums)):
            if nums[i] == nums[j]:
                return True

    return False


# input
nums = [1, 2, 3, 1]

# function call
result = contains_duplicate(nums)

# output
print(result)
# Out:
# True

# %%
def contains_duplicate(nums):
    seen = set()

    for num in nums:
        if num in seen:
            return True

        seen.add(num)

    return False


# input
nums = [1, 2, 3, 1]

# function call
result = contains_duplicate(nums)

# output
print(result)
# Out:
# True

# %%
def contains_duplicate(nums):
    return len(nums) != len(set(nums))


# input
nums = [1, 2, 3, 1]

# function call
result = contains_duplicate(nums)

# output
print(result)
# Out:
# True

# %%
def contains_duplicate(nums):
    return len(nums) != len(set(nums))


# input
nums = [1, 2, 3, 1]

# function call
result = contains_duplicate(nums)

# output
print(result)
# Out:
# True

# %%
# Two loops: O(n²)
# Set way:   O(n)

# %%
# Valid Palindrome — LeetCode 125 in a simple interview style.

# %%
s = "A man, a plan, a canal: Panama"

# %%
a = ""
j=0
for i in s:
    a=a+s[j]
    j=j+1

# %%
a
# Out:
# 'A man, a plan, a canal: Panama'

# %%
my_string = "python"
reversed_string = my_string[::-1]
print(reversed_string)  # Output: "nohtyp"
# Out:
# nohtyp

# %%
my_string = "python"
reversed_string = ""

# Start at the last index (len - 1), go down to 0, step by -1
for i in range(len(my_string) - 1, -1, -1):
    reversed_string += my_string[i]

print(reversed_string)  # Output: "nohtyp"
# Out:
# nohtyp

# %%
a = ""
for i in range (len(s) -1, -1, -1):
    temp = s[i].lower().replace(',','').replace(' ', '')
    a = a + temp
print(a)
# Out:
# amanap:lanacanalpanama

# %%
a = ""
for i in range (len(s)):
    temp = s[i].lower().replace(',','').replace(' ', '').replace(':','')
    a = a + temp
    print(a)
print(a)
# Out:
# a
# a
# am
# ama
# aman
# aman
# aman
# amana
# amana
# amanap
# amanapl
# amanapla
# amanaplan
# amanaplan
# amanaplan
# amanaplana
# amanaplana
# amanaplanac
# amanaplanaca
# amanaplanacan
# amanaplanacana
# amanaplanacanal
# amanaplanacanal
# amanaplanacanal
# amanaplanacanalp
# amanaplanacanalpa
# amanaplanacanalpan
# amanaplanacanalpana
# amanaplanacanalpanam
# amanaplanacanalpanama
# amanaplanacanalpanama

# %%
def is_palindrome(s):
    cleaned = ""

    for char in s:
        if char.isalnum():
            cleaned += char.lower()

    print(cleaned)

    return cleaned == cleaned[::-1]


# input
s = "A man, a plan, a canal: Panama"

# function call
result = is_palindrome(s)

# output
print(result)
# Out:
# amanaplanacanalpanama
# True

# %%
txt = "Company12"

x = txt.isalnum()

print(x)
# Out:
# True

# %%
# Time: O(n)

# Space: O(n)

# %%
def is_palindrome(s):
    left = 0
    right = len(s) - 1

    while left < right:

        # skip non-alphanumeric from left
        while left < right and not s[left].isalnum():
            left += 1

        # skip non-alphanumeric from right
        while left < right and not s[right].isalnum():
            right -= 1

        # compare lowercase characters
        if s[left].lower() != s[right].lower():
            return False

        left += 1
        right -= 1

    return True


# input
s = "A  man, a plan, a canal: Panama"

# function call
result = is_palindrome(s)

# output
print(result)
# Out:
# True

# %%
def is_palindrome(s):
    cleaned = ""

    for char in s:
        if char.isalnum():
            cleaned += char.lower()

    return cleaned == cleaned[::-1]


s = "A  man, a plan, a canal: Panama"
print(is_palindrome(s))
# Out:
# True

# %%
def roman_to_int(s):
    values = {
        "I": 1,
        "V": 5,
        "X": 10,
        "L": 50,
        "C": 100,
        "D": 500,
        "M": 1000
    }

    total = 0

    for i in range(len(s)):
        current_value = values[s[i]]
        next_value = values[s[i + 1]] if i + 1 < len(s) else 0

        if current_value < next_value:
            total -= current_value
        else:
            total += current_value

    return total


print(roman_to_int("III"))      # 3
print(roman_to_int("LVIII"))    # 58
print(roman_to_int("MCMXCIV"))  # 1994
# Out:
# 3
# 58
# 1994

# %%
def roman_to_int(s):
    roman = {
        "I": 1,
        "V": 5,
        "X": 10,
        "L": 50,
        "C": 100,
        "D": 500,
        "M": 1000
    }

    total = 0
    i = 0

    while i < len(s):
        if i + 1 < len(s) and s[i] == "I" and s[i + 1] == "V":
            total += 4
            i += 2
        elif i + 1 < len(s) and s[i] == "I" and s[i + 1] == "X":
            total += 9
            i += 2
        elif i + 1 < len(s) and s[i] == "X" and s[i + 1] == "L":
            total += 40
            i += 2
        elif i + 1 < len(s) and s[i] == "X" and s[i + 1] == "C":
            total += 90
            i += 2
        elif i + 1 < len(s) and s[i] == "C" and s[i + 1] == "D":
            total += 400
            i += 2
        elif i + 1 < len(s) and s[i] == "C" and s[i + 1] == "M":
            total += 900
            i += 2
        else:
            total += roman[s[i]]
            i += 1

    return total


# input
s = "MCMXCIV"

# function call
result = roman_to_int(s)

# output
print(result)
# Out:
# 1994

# %%
def roman_to_int(s):
    values = {
        "I": 1,
        "V": 5,
        "X": 10,
        "L": 50,
        "C": 100,
        "D": 500,
        "M": 1000
    }

    special = {
        "IV": 4,
        "IX": 9,
        "XL": 40,
        "XC": 90,
        "CD": 400,
        "CM": 900
    }

    total = 0
    i = 0

    while i < len(s):
        two_chars = s[i:i + 2]

        if two_chars in special:
            total += special[two_chars]
            i += 2
        else:
            total += values[s[i]]
            i += 1

    return total


# input
s = "MCMXCIV"

# function call
result = roman_to_int(s)

# output
print(result)
# Out:
# 1994

# %%
#First Unique Character in a String	387	Easy	Frequency dict, order preservation

# %%
def first_unique_char(s):

    freq = {}

    for char in s:

        freq[char] = freq.get(char, 0) + 1

    for i, char in enumerate(s):

        if freq[char] == 1:

            return i

    return -1

print(first_unique_char("leetcode"))      # 0

print(first_unique_char("loveleetcode"))  # 2

print(first_unique_char("aabb"))          # -1

print(first_unique_char(""))
# Out:
# 0
# 2
# -1
# -1

# %%
s="leetcode"
freq = {}
for char in s:
    if char in  freq:
        freq[char]+= 1
    else:
        freq[char] = 1
freq
# Out:
# {'l': 1, 'e': 3, 't': 1, 'c': 1, 'o': 1, 'd': 1}

# %%
s="leetcode"
freq = {}
for char in s:
    freq[char] = freq.get(char,0)+1
freq
# Out:
# {'l': 1, 'e': 3, 't': 1, 'c': 1, 'o': 1, 'd': 1}

# %%
def first_unique_char(s):
    freq = {}

    for char in s:
        freq[char] = freq.get(char, 0) + 1

    for i, char in enumerate(s):
        if freq[char] == 1:
            return i

    return -1


print(first_unique_char("leetcode"))      # 0
print(first_unique_char("loveleetcode"))  # 2
print(first_unique_char("aabb"))          # -1
print(first_unique_char(""))              # -1
# Out:
# 0
# 2
# -1
# -1

# %%
from collections import Counter

def first_unique_char(s):
    freq = Counter(s)

    for i, char in enumerate(s):
        if freq[char] == 1:
            return i

    return -1


print(first_unique_char("leetcode"))
# Out:
# 0

# %%
# Majority Element	169	Easy	Counting / Boyer-Moore?

# %%
def majority_element(nums):
    freq = {}

    for num in nums:
        if num in freq:
            freq[num] += 1
        else:
            freq[num] = 1
    print(freq)
    n = len(nums)

    for num in freq:
        if freq[num] > n // 2:
            return num


# input
nums = [3, 2, 3]

# function call
result = majority_element(nums)

# output
print(result)
# Out:
# {3: 2, 2: 1}
# 3

# %%
#Intersection of Two Arrays	349	Easy	Set operations (mirrors JOIN logic

# %%
nums1 = [1, 2, 2, 1]
nums2 = [2, 2]

# %%
def intersection_array(num1, num2):
    n1=len(nums1)
    n2=len(nums2)

    result=[]

    for i in range(n1):
        if num1[i] in nums2 and num1[i] not  in result:
            result.append(num1[i])

    print(result)

# %%
intersection_array(nums1, nums2)
# Out:
# [2]

# %%
def intersection(nums1, nums2):
    result = []

    for num1 in nums1:
        for num2 in nums2:
            if num1 == num2 and num1 not in result:
                result.append(num1)

    return result


# input
nums1 = [1, 2, 2, 1]
nums2 = [2, 2]

# function call
result = intersection(nums1, nums2)

# output
print(result)
# Out:
# [2]

# %%
def intersection(nums1, nums2):
    lookup = set(nums1)
    result = set()

    for num in nums2:
        if num in lookup:
            result.add(num)

    return list(result)


# input
nums1 = [1, 2, 2, 1]
nums2 = [2, 2]

# function call
result = intersection(nums1, nums2)

# output
print(result)
# Out:
# [2]

# %%
def intersection(nums1, nums2):
    return list(set(nums1) & set(nums2))


print(intersection([1, 2, 2, 1], [2, 2]))
# Out:
# [2]

# %%
	# Intersection of Two Arrays II	350	Easy	Counter intersection (handles duplicates)

# %%
def intersect(nums1, nums2):
    result = []
    used = [False] * len(nums2)

    for i in range(len(nums1)):
        for j in range(len(nums2)):
            if nums1[i] == nums2[j] and used[j] == False:
                result.append(nums1[i])
                used[j] = True
                break

    return result


# input
nums1 = [1, 2, 2, 1]
nums2 = [2, 2]

# function call
result = intersect(nums1, nums2)

# output
print(result)
# Out:
# [2, 2]

# %%
def intersect(nums1, nums2):
    freq = {}

    for num in nums1:
        freq[num] = freq.get(num, 0) + 1

    result = []

    for num in nums2:
        if num in freq and freq[num] > 0:
            result.append(num)
            freq[num] -= 1

    return result


# input
nums1 = [1, 2, 2, 1]
nums2 = [2, 2]

# function call
result = intersect(nums1, nums2)

# output
print(result)
# Out:
# [2, 2]

# %%
def intersect(nums1, nums2):
    if len(nums1) > len(nums2):
        nums1, nums2 = nums2, nums1

    freq = {}

    for num in nums1:
        freq[num] = freq.get(num, 0) + 1

    result = []

    for num in nums2:
        if freq.get(num, 0) > 0:
            result.append(num)
            freq[num] -= 1

    return result


print(intersect([1, 2, 2, 1], [2, 2]))
print(intersect([4, 9, 5], [9, 4, 9, 8, 4]))
# Out:
# [2, 2]
# [9, 4]

# %%
#10	Single Number	136	Easy	Set/XOR — finding the odd one out

# %%
def single_number(nums):
    freq = {}

    for num in nums:
        freq[num] = freq.get(num, 0) + 1

    for num in freq:
        if freq[num] == 1:
            return num


# input
nums = [4, 1, 2, 1, 2]

# function call
result = single_number(nums)

# output
print(result)
# Out:
# 4

# %%
def single_number(nums):
    seen = set()

    for num in nums:
        if num in seen:
            seen.remove(num)
        else:
            seen.add(num)

    return seen.pop()


# input
nums = [4, 1, 2, 1, 2]

# function call
result = single_number(nums)

# output
print(result)
# Out:
# 4

# %%
def single_number(nums):
    result = 0

    for num in nums:
        result = result ^ num

    return result


# input
nums = [4, 1, 2, 1, 2]

# function call
result = single_number(nums)

# output
print(result)
# Out:
# 4

# %%
def max_profit(prices):
    max_profit_value = 0

    for buy_day in range(len(prices)):
        for sell_day in range(buy_day + 1, len(prices)):
            profit = prices[sell_day] - prices[buy_day]

            if profit > max_profit_value:
                max_profit_value = profit

    return max_profit_value


# input
prices = [7, 1, 5, 3, 6, 4]

# function call
result = max_profit(prices)

# output
print(result)
# Out:
# 5

# %%
def max_profit(prices):
    min_price = float("inf")
    max_profit_value = 0

    for price in prices:
        if price < min_price:
            min_price = price

        profit = price - min_price

        if profit > max_profit_value:
            max_profit_value = profit

    return max_profit_value


# input
prices = [7, 1, 5, 3, 6, 4]

# function call
result = max_profit(prices)

# output
print(result)
# Out:
# 5

# %%
def max_profit(prices):
    min_price = prices[0]
    best_profit = 0

    for price in prices[1:]:
        best_profit = max(best_profit, price - min_price)
        min_price = min(min_price, price)

    return best_profit


print(max_profit([7, 1, 5, 3, 6, 4]))
print(max_profit([7, 6, 4, 3, 1]))
# Out:
# 5
# 0

# %%
# 12	Move Zeroes	283	Easy	In-place array mutation, two pointers
# 13	Fizz Buzz	412	Easy	Classic opener — flow control
# 14	Plus One	66	Easy	Array digit manipulation, carry logic
# 15	Merge Sorted Array	88	Easy	Two-pointer merge (core of merge-sort/joins)
# 16	Missing Number	268	Easy	Math/set — gap detection
# 17	Word Pattern	290	Easy	Bijective dict mapping
# 18	Group Anagrams	49	Medium	Dict-of-lists bucketing — grouping/aggregation
# 19	Top K Frequent Elements	347	Medium	Counter + heap — top-N, very DE-relevant

# %%
nums = [0, 1, 0, 3, 12]

# %%
[1, 3, 12, 0, 0]
# Out:
# [1, 3, 12, 0, 0]

# %%
def move_zeroes(nums):
    write = 0

    for read in range(len(nums)):
        if nums[read] != 0:
            nums[write] = nums[read]
            write += 1

    while write < len(nums):
        nums[write] = 0
        write += 1

    return nums


nums = [0, 1, 0, 3, 12]
print(move_zeroes(nums))
# Out:
# [1, 3, 12, 0, 0]

# %%
#13. Fizz Buzz — LeetCode 412

# %%
# multiple of 3       → Fizz
# multiple of 5       → Buzz
# multiple of 3 and 5 → FizzBuzz
# otherwise           → number as string

# %%
def fizz_buzz(n):
    result = []

    for i in range(1, n + 1):
        if i % 15 == 0:
            result.append("FizzBuzz")
        elif i % 3 == 0:
            result.append("Fizz")
        elif i % 5 == 0:
            result.append("Buzz")
        else:
            result.append(str(i))

    return result


print(fizz_buzz(15))
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz']

# %%
# Time: O(n)
# Space: O(n)

# %%
# 14. Plus One — LeetCode 66

# %%
def plus_one(digits):
    for i in range(len(digits) - 1, -1, -1):
        if digits[i] < 9:
            digits[i] += 1
            return digits

        digits[i] = 0

    return [1] + digits


print(plus_one([1, 2, 3]))
print(plus_one([9, 9, 9]))
# Out:
# [1, 2, 4]
# [1, 0, 0, 0]

# %%
# 15. Merge Sorted Array — LeetCode 88

# %%
nums1 = [1, 2, 3, 0, 0, 0]
m = 3

nums2 = [2, 5, 6]
n = 3

# %%
[1, 2, 2, 3, 5, 6]
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
nums1+nums2
# Out:
# [1, 2, 3, 0, 0, 0, 2, 5, 6]

# %%
def merge(nums1, m, nums2, n):
    i = m - 1
    j = n - 1
    k = m + n - 1

    while j >= 0:
        if i >= 0 and nums1[i] > nums2[j]:
            nums1[k] = nums1[i]
            i -= 1
        else:
            nums1[k] = nums2[j]
            j -= 1

        k -= 1

    return nums1


nums1 = [1, 2, 3, 0, 0, 0]
nums2 = [2, 5, 6]

print(merge(nums1, 3, nums2, 3))
# Out:
# [1, 2, 2, 3, 5, 6]

# %%
def missing_number(nums):
    seen = set(nums)

    for i in range(len(nums) + 1):
        if i not in seen:
            return i


print(missing_number([3, 0, 1]))
# Out:
# 2

# %%
def missing_number(nums):
    n = len(nums)
    expected_sum = n * (n + 1) // 2
    actual_sum = sum(nums)

    return expected_sum - actual_sum


print(missing_number([3, 0, 1]))
print(missing_number([0, 1]))
# Out:
# 2
# 2

# %%
# 17. Word Pattern — LeetCode 290

# %%
def word_pattern(pattern, s):
    words = s.split()

    if len(pattern) != len(words):
        return False

    char_to_word = {}
    word_to_char = {}

    for char, word in zip(pattern, words):
        if char in char_to_word:
            if char_to_word[char] != word:
                return False
        else:
            char_to_word[char] = word

        if word in word_to_char:
            if word_to_char[word] != char:
                return False
        else:
            word_to_char[word] = char

    return True


print(word_pattern("abba", "dog cat cat dog"))
print(word_pattern("abba", "dog cat cat fish"))
print(word_pattern("abba", "dog dog dog dog"))
# Out:
# True
# False
# False

# %%
strs = ["eat", "tea", "tan", "ate", "nat", "bat"]

# %%
def group_anagrams(strs):
    groups = {}

    for word in strs:
        key = "".join(sorted(word))
        print(key)

        if key not in groups:
            groups[key] = []

        groups[key].append(word)

    return list(groups.values())


strs = ["eat", "tea", "tan", "ate", "nat", "bat"]
print(group_anagrams(strs))
# Out:
# aet
# aet
# ant
# aet
# ant
# abt
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat']]
