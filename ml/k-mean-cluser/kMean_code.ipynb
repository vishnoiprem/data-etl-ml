# %%
import numpy as np
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# %%
data = np.array([[1, 2], [2, 3], [3, 4], [8, 7], [9, 8], [10, 9], [5, 5]])
data
# Out:
# array([[ 1,  2],
#        [ 2,  3],
#        [ 3,  4],
#        [ 8,  7],
#        [ 9,  8],
#        [10,  9],
#        [ 5,  5]])

# %%
scaler = StandardScaler()
data_normalized = scaler.fit_transform(data)
data_normalized
# Out:
# array([[-1.32911403, -1.40449377],
#        [-1.02899151, -0.99484975],
#        [-0.72886899, -0.58520574],
#        [ 0.77174363,  0.64372631],
#        [ 1.07186616,  1.05337032],
#        [ 1.37198868,  1.46301434],
#        [-0.12862394, -0.17556172]])

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(data_normalized)
# Out:
# KMeans(n_clusters=2, random_state=0)

# %%
centroids = kmeans.cluster_centers_
labels = kmeans.labels_

# %%
labels
# Out:
# array([1, 1, 1, 0, 0, 0, 1], dtype=int32)

# %%
centroids
# Out:
# array([[ 1.07186616,  1.05337032],
#        [-0.80389962, -0.79002774]])

# %%
plt.scatter(data_normalized[:, 0], data_normalized[:, 1], c=labels, cmap='viridis')
plt.scatter(centroids[:, 0], centroids[:, 1], s=300, c='red')  # Centroids in red
plt.show()
