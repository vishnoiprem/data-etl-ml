# %% [markdown]
# # Multi-lora Serving

# %% [markdown]
# ## Library Installation

# %%
! pip install -U sagemaker==2.230.0 boto3==1.35.9 python-dotenv==1.0.1 sagemaker-studio-image-build==0.6.0
# Out:
# Requirement already satisfied: sagemaker==2.230.0 in /opt/conda/lib/python3.10/site-packages (2.230.0)
# Requirement already satisfied: boto3==1.35.9 in /opt/conda/lib/python3.10/site-packages (1.35.9)
# Requirement already satisfied: python-dotenv==1.0.1 in /opt/conda/lib/python3.10/site-packages (1.0.1)
# Requirement already satisfied: sagemaker-studio-image-build==0.6.0 in /opt/conda/lib/python3.10/site-packages (0.6.0)
# Requirement already satisfied: attrs<24,>=23.1.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (23.2.0)
# Requirement already satisfied: cloudpickle==2.2.1 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (2.2.1)
# Requirement already satisfied: docker in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (7.1.0)
# Requirement already satisfied: google-pasta in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (0.2.0)
# Requirement already satisfied: importlib-metadata<7.0,>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (6.10.0)
# Requirement already satisfied: jsonschema in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (4.17.3)
# Requirement already satisfied: numpy<2.0,>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (23.2)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (2.1.4)
# Requirement already satisfied: pathos in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (0.3.2)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (4.2.2)
# Requirement already satisfied: protobuf<5.0,>=3.12 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (4.24.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (5.9.8)
# Requirement already satisfied: pyyaml~=6.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (2.32.3)
# Requirement already satisfied: schema in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (0.7.7)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (1.0.1)
# Requirement already satisfied: tblib<4,>=1.7.0 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (2.0.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (4.66.4)
# Requirement already satisfied: urllib3<3.0.0,>=1.26.8 in /opt/conda/lib/python3.10/site-packages (from sagemaker==2.230.0) (1.26.19)
# Requirement already satisfied: botocore<1.36.0,>=1.35.9 in /opt/conda/lib/python3.10/site-packages (from boto3==1.35.9) (1.35.19)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from boto3==1.35.9) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in /opt/conda/lib/python3.10/site-packages (from boto3==1.35.9) (0.10.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.9->boto3==1.35.9) (2.9.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata<7.0,>=1.4.0->sagemaker==2.230.0) (3.19.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->sagemaker==2.230.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->sagemaker==2.230.0) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->sagemaker==2.230.0) (2024.7.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from google-pasta->sagemaker==2.230.0) (1.16.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema->sagemaker==2.230.0) (0.20.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->sagemaker==2.230.0) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas->sagemaker==2.230.0) (2024.1)
# Requirement already satisfied: ppft>=1.7.6.8 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker==2.230.0) (1.7.6.8)
# Requirement already satisfied: dill>=0.3.8 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker==2.230.0) (0.3.8)
# Requirement already satisfied: pox>=0.3.4 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker==2.230.0) (0.3.4)
# Requirement already satisfied: multiprocess>=0.70.16 in /opt/conda/lib/python3.10/site-packages (from pathos->sagemaker==2.230.0) (0.70.16)

# %% [markdown]
# ## Setup Credentials

# %%
import sagemaker
import boto3

sess = sagemaker.Session()

s3_bucket = sess.default_bucket()
region = boto3.session.Session().region_name
role = sagemaker.get_execution_role()

print(f"{role =}")
print(f"{region =}")
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# role ='arn:aws:iam::466407698387:role/service-role/AmazonSageMaker-ExecutionRole-20240729T083760'
# region ='ap-south-1'

# %% [markdown]
# # Setup
# - inline policy with principal
# - model access
# - HF token in .env file

# %%
import json
import dotenv
print(dotenv.load_dotenv('./.env', override=True))

endpoint_name = 'multi-lora-model'
instance_type = 'ml.g5.2xlarge' # ml.g5.xlarge
base_model = "mistralai/Mistral-7B-Instruct-v0.1"

print("https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.1")
policy = {
    "Version": "2012-10-17",
    "Statement": [
        {
            "Effect": "Allow",
            "Action": "iam:PassRole",
            "Resource": role,
        }
    ]
}

principal = {
    "Effect": "Allow",
    "Principal": {
        "Service": "codebuild.amazonaws.com"
    },
    "Action": "sts:AssumeRole"
}

print(json.dumps(policy, indent=4))
print("\n\n")
print(json.dumps(principal, indent=4))
# Out:
# True
# https://huggingface.co/mistralai/Mistral-7B-Instruct-v0.1
# {
#     "Version": "2012-10-17",
#     "Statement": [
#         {
#             "Effect": "Allow",
#             "Action": "iam:PassRole",
#             "Resource": "arn:aws:iam::466407698387:role/service-role/AmazonSageMaker-ExecutionRole-20240729T083760"
#         }
#     ]
# }
#
#
#
# {
#     "Effect": "Allow",
#     "Principal": {
#         "Service": "codebuild.amazonaws.com"
#     },
#     "Action": "sts:AssumeRole"
# }

# %% [markdown]
# # Upload Dockerfile to AWS ECR

# %%
# !sm-docker build . --file ./Dockerfile --repository "lorax:latest"
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# ..................[Container] 2024/09/15 12:19:48.550341 Running on CodeBuild On-demand
#
# [Container] 2024/09/15 12:19:48.550351 Waiting for agent ping
# [Container] 2024/09/15 12:19:50.758207 Waiting for DOWNLOAD_SOURCE
# [Container] 2024/09/15 12:19:50.928415 Phase is DOWNLOAD_SOURCE
# [Container] 2024/09/15 12:19:50.962215 CODEBUILD_SRC_DIR=/codebuild/output/src33080977/src
# [Container] 2024/09/15 12:19:50.962723 YAML location is /codebuild/output/src33080977/src/buildspec.yml
# [Container] 2024/09/15 12:19:50.964654 Setting HTTP client timeout to higher timeout for S3 source
# [Container] 2024/09/15 12:19:50.964917 Processing environment variables
# [Container] 2024/09/15 12:19:51.006416 No runtime version selected in buildspec.
# [Container] 2024/09/15 12:19:51.021281 Moving to directory /codebuild/output/src33080977/src
# [Container] 2024/09/15 12:19:51.022654 Unable to initialize cache download: no paths specified to be cached
# [Container] 2024/09/15 12:19:51.023343 Configuring ssm agent with target id: codebuild:f71fcc09-d6f4-4a12-b7e5-19a7b368d4bd
# [Container] 2024/09/15 12:19:51.023623 Successfully updated ssm agent configuration
# [Container] 2024/09/15 12:19:51.023849 Registering with agent
# [Container] 2024/09/15 12:19:51.057978 Phases found in YAML: 3
# [Container] 2024/09/15 12:19:51.058001  BUILD: 4 commands
# [Container] 2024/09/15 12:19:51.058006  POST_BUILD: 3 commands
# [Container] 2024/09/15 12:19:51.058010  PRE_BUILD: 9 commands
# [Container] 2024/09/15 12:19:51.058337 Phase complete: DOWNLOAD_SOURCE State: SUCCEEDED
# [Container] 2024/09/15 12:19:51.058349 Phase context status code:  Message:
# [Container] 2024/09/15 12:19:51.120533 Entering phase INSTALL
# [Container] 2024/09/15 12:19:51.123093 Phase complete: INSTALL State: SUCCEEDED
# [Container] 2024/09/15 12:19:51.123106 Phase context status code:  Message:
# [Container] 2024/09/15 12:19:51.152733 Entering phase PRE_BUILD
# [Container] 2024/09/15 12:19:51.185063 Running command echo Logging in to Amazon ECR...
# Logging in to Amazon ECR...
#
# [Container] 2024/09/15 12:19:51.189523 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2024/09/15 12:19:52.555380 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 763104351884)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2024/09/15 12:19:53.093537 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 217643126080)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2024/09/15 12:19:53.634600 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 727897471807)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2024/09/15 12:19:54.166897 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 626614931356)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2024/09/15 12:19:54.706261 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 683313688378)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2024/09/15 12:19:55.256731 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 520713654638)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2024/09/15 12:19:55.794171 Running command $(aws ecr get-login --no-include-email --region $AWS_DEFAULT_REGION --registry-ids 462105765813)
# WARNING! Using --password via the CLI is insecure. Use --password-stdin.
# WARNING! Your password will be stored unencrypted in /root/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded
#
# [Container] 2024/09/15 12:19:56.323114 Phase complete: PRE_BUILD State: SUCCEEDED
# [Container] 2024/09/15 12:19:56.323130 Phase context status code:  Message:
# [Container] 2024/09/15 12:19:56.357018 Entering phase BUILD
# [Container] 2024/09/15 12:19:56.357953 Running command echo Build started on `date`
# Build started on Sun Sep 15 12:19:56 UTC 2024
#
# [Container] 2024/09/15 12:19:56.366190 Running command echo Building the Docker image...
# Building the Docker image...
#
# [Container] 2024/09/15 12:19:56.370338 Running command docker build -t $IMAGE_REPO_NAME:$IMAGE_TAG . --file ./Dockerfile
# Sending build context to Docker daemon  37.89kB
# Step 1/4 : FROM ghcr.io/predibase/lorax:main
# main: Pulling from predibase/lorax
# bccd10f490ab: Pulling fs layer
# edd1dba56169: Pulling fs layer
# e06eb1b5c4cc: Pulling fs layer
# 7f308a765276: Pulling fs layer
# 3af11d09e9cd: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# 6b4c4770fd50: Pulling fs layer
# 0ae378a3890a: Pulling fs layer
# 1b8f9390ff0a: Pulling fs layer
# 310d4e9a796e: Pulling fs layer
# da5ad7ecabcf: Pulling fs layer
# 926faddd499f: Pulling fs layer
# 94d505711af0: Pulling fs layer
# 0bbfcbef228d: Pulling fs layer
# c9a236d0c05e: Pulling fs layer
# 3a33b7716a54: Pulling fs layer
# 9d4de7aa0a50: Pulling fs layer
# 2aa83dae4259: Pulling fs layer
# aab8361cc299: Pulling fs layer
# b00c32f4c19b: Pulling fs layer
# 3db4a4d1bfc4: Pulling fs layer
# 3fee50f59169: Pulling fs layer
# 19573633a85c: Pulling fs layer
# d7c6153adec5: Pulling fs layer
# 2d1314bacf14: Pulling fs layer
# 1846ebd59c97: Pulling fs layer
# b9d84cad0817: Pulling fs layer
# 336d79b31fa4: Pulling fs layer
# 59e395c37072: Pulling fs layer
# af14228ce1fc: Pulling fs layer
# 24b7f6a8e73b: Pulling fs layer
# 555134dfa4c5: Pulling fs layer
# b1e45fa830ed: Pulling fs layer
# 94d505711af0: Waiting
# 0bbfcbef228d: Waiting
# c9a236d0c05e: Waiting
# 3a33b7716a54: Waiting
# 9d4de7aa0a50: Waiting
# 2aa83dae4259: Waiting
# aab8361cc299: Waiting
# b00c32f4c19b: Waiting
# 3db4a4d1bfc4: Waiting
# 3fee50f59169: Waiting
# 7f308a765276: Waiting
# 3af11d09e9cd: Waiting
# 19573633a85c: Waiting
# 4f4fb700ef54: Waiting
# d7c6153adec5: Waiting
# 6b4c4770fd50: Waiting
# 2d1314bacf14: Waiting
# 0ae378a3890a: Waiting
# 1b8f9390ff0a: Waiting
# 310d4e9a796e: Waiting
# da5ad7ecabcf: Waiting
# 926faddd499f: Waiting
# 1846ebd59c97: Waiting
# b9d84cad0817: Waiting
# 336d79b31fa4: Waiting
# 59e395c37072: Waiting
# af14228ce1fc: Waiting
# 24b7f6a8e73b: Waiting
# 555134dfa4c5: Waiting
# b1e45fa830ed: Waiting
# edd1dba56169: Verifying Checksum
# edd1dba56169: Download complete
# 7f308a765276: Download complete
# bccd10f490ab: Verifying Checksum
# bccd10f490ab: Download complete
# 3af11d09e9cd: Verifying Checksum
# 3af11d09e9cd: Download complete
# 4f4fb700ef54: Verifying Checksum
# 4f4fb700ef54: Download complete
# bccd10f490ab: Pull complete
# e06eb1b5c4cc: Verifying Checksum
# e06eb1b5c4cc: Download complete
# edd1dba56169: Pull complete
# 6b4c4770fd50: Verifying Checksum
# 6b4c4770fd50: Download complete
# e06eb1b5c4cc: Pull complete
# 7f308a765276: Pull complete
# 3af11d09e9cd: Pull complete
# 4f4fb700ef54: Pull complete
# 6b4c4770fd50: Pull complete
# 1b8f9390ff0a: Verifying Checksum
# 1b8f9390ff0a: Download complete
# da5ad7ecabcf: Download complete
# 310d4e9a796e: Verifying Checksum
# 310d4e9a796e: Download complete
# 94d505711af0: Verifying Checksum
# 94d505711af0: Download complete
# 0bbfcbef228d: Verifying Checksum
# 0bbfcbef228d: Download complete
# c9a236d0c05e: Verifying Checksum
# c9a236d0c05e: Download complete
# 3a33b7716a54: Verifying Checksum
# 3a33b7716a54: Download complete
# 926faddd499f: Verifying Checksum
# 926faddd499f: Download complete
# 2aa83dae4259: Verifying Checksum
# 2aa83dae4259: Download complete
# aab8361cc299: Verifying Checksum
# aab8361cc299: Download complete
# b00c32f4c19b: Verifying Checksum
# b00c32f4c19b: Download complete
# 3db4a4d1bfc4: Download complete
# 9d4de7aa0a50: Verifying Checksum
# 9d4de7aa0a50: Download complete
# 19573633a85c: Verifying Checksum
# 19573633a85c: Download complete
# d7c6153adec5: Verifying Checksum
# d7c6153adec5: Download complete
# 2d1314bacf14: Verifying Checksum
# 2d1314bacf14: Download complete
# 1846ebd59c97: Verifying Checksum
# 1846ebd59c97: Download complete
# b9d84cad0817: Verifying Checksum
# b9d84cad0817: Download complete
# 336d79b31fa4: Verifying Checksum
# 336d79b31fa4: Download complete
# 59e395c37072: Verifying Checksum
# 59e395c37072: Download complete
# af14228ce1fc: Verifying Checksum
# af14228ce1fc: Download complete
# 24b7f6a8e73b: Verifying Checksum
# 24b7f6a8e73b: Download complete
# 555134dfa4c5: Download complete
# b1e45fa830ed: Verifying Checksum
# b1e45fa830ed: Download complete
# 3fee50f59169: Verifying Checksum
# 3fee50f59169: Download complete
# 0ae378a3890a: Verifying Checksum
# 0ae378a3890a: Download complete
# 0ae378a3890a: Pull complete
# 1b8f9390ff0a: Pull complete
# 310d4e9a796e: Pull complete
# da5ad7ecabcf: Pull complete
# 926faddd499f: Pull complete
# 94d505711af0: Pull complete
# 0bbfcbef228d: Pull complete
# c9a236d0c05e: Pull complete
# 3a33b7716a54: Pull complete
# 9d4de7aa0a50: Pull complete
# 2aa83dae4259: Pull complete
# aab8361cc299: Pull complete
# b00c32f4c19b: Pull complete
# 3db4a4d1bfc4: Pull complete
# 3fee50f59169: Pull complete
# 19573633a85c: Pull complete
# d7c6153adec5: Pull complete
# 2d1314bacf14: Pull complete
# 1846ebd59c97: Pull complete
# b9d84cad0817: Pull complete
# 336d79b31fa4: Pull complete
# 59e395c37072: Pull complete
# af14228ce1fc: Pull complete
# 24b7f6a8e73b: Pull complete
# 555134dfa4c5: Pull complete
#
# b1e45fa830ed: Pull complete
# Digest: sha256:70f66620436069589eaf40725cb6c0f2c78efb80b1a8de987936ea2344b492a5
# Status: Downloaded newer image for ghcr.io/predibase/lorax:main
#  ---> 57ff2ccf576a
# Step 2/4 : COPY entrypoint.sh .
#  ---> a32ee29695a3
# Step 3/4 : RUN chmod +x entrypoint.sh
#  ---> Running in 7d2a40757bdd
# Removing intermediate container 7d2a40757bdd
#  ---> 79c11d9a8000
# Step 4/4 : ENTRYPOINT ["./entrypoint.sh"]
#  ---> Running in 3b1c999bec01
# Removing intermediate container 3b1c999bec01
#  ---> c2f6c6dfc96c
# Successfully built c2f6c6dfc96c
# Successfully tagged lorax:latest
#
# [Container] 2024/09/15 12:25:55.380790 Running command docker tag $IMAGE_REPO_NAME:$IMAGE_TAG $AWS_ACCOUNT_ID.dkr.ecr.$AWS_DEFAULT_REGION.amazonaws.com/$IMAGE_REPO_NAME:$IMAGE_TAG
#
# [Container] 2024/09/15 12:25:55.490611 Phase complete: BUILD State: SUCCEEDED
# [Container] 2024/09/15 12:25:55.491443 Phase context status code:  Message:
# [Container] 2024/09/15 12:25:55.528334 Entering phase POST_BUILD
# [Container] 2024/09/15 12:25:55.529222 Running command echo Build completed on `date`
# Build completed on Sun Sep 15 12:25:55 UTC 2024
#
# [Container] 2024/09/15 12:25:55.537014 Running command echo Pushing the Docker image...
# Pushing the Docker image...
#
# [Container] 2024/09/15 12:25:55.541077 Running command docker push $AWS_ACCOUNT_ID.dkr.ecr.$AWS_DEFAULT_REGION.amazonaws.com/$IMAGE_REPO_NAME:$IMAGE_TAG
# The push refers to repository [466407698387.dkr.ecr.ap-south-1.amazonaws.com/lorax]
# 269215a03605: Preparing
# bc8594a6ea77: Preparing
# d2ed3d665f59: Preparing
# 5f70bf18a086: Preparing
# a0b59d32fac9: Preparing
# 1c891d7df2a6: Preparing
# 3fad35891e7b: Preparing
# 4056c98ba5bf: Preparing
# ac9373d99be7: Preparing
# ac036be5c1df: Preparing
# d17129e196ee: Preparing
# 5aad2b720233: Preparing
# 5f70bf18a086: Preparing
# 729846ac9454: Preparing
# 05d8382e4ce4: Preparing
# 4e1224ab3037: Preparing
# 14dbe4144abc: Preparing
# 6aa27f2a22aa: Preparing
# 6f082dba114f: Preparing
# 20b4c422830e: Preparing
# e81d9a505cbc: Preparing
# 13d9f87d936a: Preparing
# f029e31023c2: Preparing
# 53defe18739f: Preparing
# 6c36957c8295: Preparing
# d25989bc6545: Preparing
# f6eacc323933: Preparing
# 613cc5ae1289: Preparing
# 6b2c9e37b5c4: Preparing
# c30c57bde2fd: Preparing
# 7fc178891e0b: Preparing
# 5f70bf18a086: Preparing
# e942261d196e: Preparing
# eeb5315df33c: Preparing
# 022bf74291b2: Preparing
# 4cd407952594: Preparing
# 5498e8c22f69: Preparing
# 20b4c422830e: Waiting
# e81d9a505cbc: Waiting
# 13d9f87d936a: Waiting
# f029e31023c2: Waiting
# 53defe18739f: Waiting
# 6c36957c8295: Waiting
# d25989bc6545: Waiting
# 1c891d7df2a6: Waiting
# 3fad35891e7b: Waiting
# 4056c98ba5bf: Waiting
# ac9373d99be7: Waiting
# ac036be5c1df: Waiting
# d17129e196ee: Waiting
# 5aad2b720233: Waiting
# 729846ac9454: Waiting
# 05d8382e4ce4: Waiting
# 4e1224ab3037: Waiting
# 14dbe4144abc: Waiting
# 6aa27f2a22aa: Waiting
# 6f082dba114f: Waiting
# f6eacc323933: Waiting
# 613cc5ae1289: Waiting
# 6b2c9e37b5c4: Waiting
# c30c57bde2fd: Waiting
# 7fc178891e0b: Waiting
# e942261d196e: Waiting
# eeb5315df33c: Waiting
# 022bf74291b2: Waiting
# 4cd407952594: Waiting
# 5498e8c22f69: Waiting
# d2ed3d665f59: Layer already exists
# a0b59d32fac9: Layer already exists
# 5f70bf18a086: Layer already exists
# 4056c98ba5bf: Layer already exists
# 1c891d7df2a6: Layer already exists
# 3fad35891e7b: Layer already exists
# ac9373d99be7: Layer already exists
# ac036be5c1df: Layer already exists
# d17129e196ee: Layer already exists
# 5aad2b720233: Layer already exists
# 729846ac9454: Layer already exists
# 05d8382e4ce4: Layer already exists
# 4e1224ab3037: Layer already exists
# 14dbe4144abc: Layer already exists
# 6aa27f2a22aa: Layer already exists
# 20b4c422830e: Layer already exists
# 6f082dba114f: Layer already exists
# e81d9a505cbc: Layer already exists
# 13d9f87d936a: Layer already exists
# f029e31023c2: Layer already exists
# 53defe18739f: Layer already exists
# 269215a03605: Pushed
# 6c36957c8295: Layer already exists
# f6eacc323933: Layer already exists
# d25989bc6545: Layer already exists
# 6b2c9e37b5c4: Layer already exists
# 613cc5ae1289: Layer already exists
# c30c57bde2fd: Layer already exists
# bc8594a6ea77: Pushed
# 7fc178891e0b: Layer already exists
# e942261d196e: Layer already exists
# eeb5315df33c: Layer already exists
# 4cd407952594: Layer already exists
# 022bf74291b2: Layer already exists
# 5498e8c22f69: Pushed
# latest: digest: sha256:f3319fc9c8795a4f70e757d2b18627f4d3c1bf9a8bc3bf8603db0da5c681566b size: 8102
#
# [Container] 2024/09/15 12:26:00.754448 Phase complete: POST_BUILD State: SUCCEEDED
# [Container] 2024/09/15 12:26:00.754465 Phase context status code:  Message:
# [Container] 2024/09/15 12:26:00.802444 Set report auto-discover timeout to 5 seconds
# [Container] 2024/09/15 12:26:00.803413 Expanding base directory path:  .
# [Container] 2024/09/15 12:26:00.804953 Assembling file list
# [Container] 2024/09/15 12:26:00.804967 Expanding .
# [Container] 2024/09/15 12:26:00.806495 Expanding file paths for base directory .
# [Container] 2024/09/15 12:26:00.806505 Assembling file list
# [Container] 2024/09/15 12:26:00.806508 Expanding **/*
# [Container] 2024/09/15 12:26:00.813097 No matching auto-discover report paths found
# [Container] 2024/09/15 12:26:00.813117 Report auto-discover file discovery took 0.010673 seconds
# [Container] 2024/09/15 12:26:00.813148 Phase complete: UPLOAD_ARTIFACTS State: SUCCEEDED
# [Container] 2024/09/15 12:26:00.813155 Phase context status code:  Message:
# Image URI: 466407698387.dkr.ecr.ap-south-1.amazonaws.com/lorax:latest

# %% [markdown]
# # Deploy SageMaker model

# %%
import json
import os
import boto3
from sagemaker import Model
from sagemaker.serializers import JSONSerializer
from sagemaker.deserializers import JSONDeserializer

account_id=boto3.client('sts').get_caller_identity().get('Account')

image_uri = f"{account_id}.dkr.ecr.{region}.amazonaws.com/lorax:latest"

environment_vars = {
  'MODEL_ID': base_model,
  'MAX_BATCH_TOTAL_TOKENS': "4096",
  'MAX_CONCURRENT_REQUESTS': "256",
  'HF_TOKEN': os.getenv("HF_TOKEN"),
  'PORT': '8080',
  'NVIDIA_VISIBLE_DEVICES': 'all',
}

lorax_model = Model(
    image_uri=image_uri,
    role=role,
    env=environment_vars
)

lorax_predictor = lorax_model.deploy(
    endpoint_name=endpoint_name,
    initial_instance_count=1,
    instance_type=instance_type,
    container_startup_health_check_timeout=600,
    serializer=JSONSerializer(),
    deserializer=JSONDeserializer()
)
# Out:
# ---------------!

# %% [markdown]
# # Multi-LoRA inference

# %%
adapters = [
    {
        "name": "Named Entity Recognition (NER)",
        "url": "https://huggingface.co/predibase/conllpp",
        "adapter_id": "predibase/conllpp",
        "prompt": """Your task is a Named Entity Recognition (NER) task. \n\
            Predict the category of each entity, then place the entity into the list associated with the category in an output JSON payload.\n\
            Below is an example: \n\
            Input: EU rejects German call to boycott British lamb.\n\
            Output: {"person": [], "organization": ["EU"], "location": [], "miscellaneous": ["German", "British"]} \n\
            Now, complete the task. \n 
            Input: By the close Yorkshire had turned that into a 37-run advantage but off-spinner David had scuttled their hopes, \
                taking four for 24 in 48 balls and leaving them hanging on 119 for five and praying for rain. \n\
            Output:""",
       "expected_output": '{"person": ["David"], "organization": ["Yorkshire"], "location": [], "miscellaneous": []}'
    },
    {
        "name": "Customer support ticket classifier",
        "url": "https://huggingface.co/predibase/customer_support",
        "adapter_id": "predibase/customer_support",
        "prompt": """Consider the case of a customer contacting the support center.
            The term 'task type' refers to the reason for why the customer contacted support.
            ### The possible task types are: ### 
            - replace card
            - transfer money
            - check balance
            - order checks
            - pay bill
            - reset password
            - schedule appointment
            - get branch hours
            - none of the above

            Summarize the issue/question/reason that drove the customer to contact support:

            ### Transcript: [noise] [noise] [noise] [noise] hello hello hi i'm sorry this this call uh hello this is harper valley national bank my name is dawn how can i help you today hi oh okay my name is jennifer brown and i need to check my account balance if i could [noise] [noise] [noise] [noise] what account would you like to check um [noise] uhm my savings account please [noise] [noise] oh but the way that you're doing one moment hello yeah one moment uh huh no problem [noise] your account balance is eighty two dollars is there anything else i can help you with no i don't think so thank you so much you were very helpful thank you have a good day bye bye [noise] you too 

            ### Task Type:
            test_transcript =""",
        "expected_output": "check balance"
    }
]

# %%
import os
from transformers import AutoTokenizer
from sagemaker import Predictor
from sagemaker.serializers import JSONSerializer
from sagemaker.deserializers import JSONDeserializer
from datasets import load_dataset

def get_request_body(adapter_id: str, prompt: str):
    return {
        "inputs": prompt,
        "parameters": {
            "adapter_id": adapter_id,
            "max_new_tokens": 512,
            "adapter_source": "hub",
            "temperature": 0,
            "top_p": 0.1,
        }
    }

deployed_llm = Predictor(
    endpoint_name=endpoint_name,
    serializer=JSONSerializer(),
    deserializer=JSONDeserializer()
)

def call_endpoint(adapter):
    outputs = deployed_llm.predict(get_request_body(adapter["adapter_id"], adapter["prompt"]))
    return outputs[0]["generated_text"].strip()

for adapter in adapters:
    print(f"adapter: {adapter['name']} with url {adapter['url']} \nprompt=\n{adapter['prompt']}\n")
    print(f"expected output:  {adapter['expected_output']}\ngenerated output: {call_endpoint(adapter)}")
    print("\n ---------------------- \n")
# Out:
# adapter: Named Entity Recognition (NER) with url https://huggingface.co/predibase/conllpp
# prompt=
# Your task is a Named Entity Recognition (NER) task.
#             Predict the category of each entity, then place the entity into the list associated with the category in an output JSON payload.
#             Below is an example:
#             Input: EU rejects German call to boycott British lamb.
#             Output: {"person": [], "organization": ["EU"], "location": [], "miscellaneous": ["German", "British"]}
#             Now, complete the task.
#
#             Input: By the close Yorkshire had turned that into a 37-run advantage but off-spinner David had scuttled their hopes,                 taking four for 24 in 48 balls and leaving them hanging on 119 for five and praying for rain.
#             Output:
#
# expected output:  {"person": ["David"], "organization": ["Yorkshire"], "location": [], "miscellaneous": []}
# generated output: {"person": ["David"], "organization": ["Yorkshire"], "location": [], "miscellaneous": []}
#
#  ----------------------
#
# adapter: Customer support ticket classifier with url https://huggingface.co/predibase/customer_support
# prompt=
# Consider the case of a customer contacting the support center.
#             The term 'task type' refers to the reason for why the customer contacted support.
#             ### The possible task types are: ###
#             - replace card
#             - transfer money
#             - check balance
#             - order checks
#             - pay bill
#             - reset password
#             - schedule appointment
#             - get branch hours
#             - none of the above
#
#             Summarize the issue/question/reason that drove the customer to contact support:
#
#             ### Transcript: [noise] [noise] [noise] [noise] hello hello hi i'm sorry this this call uh hello this is harper valley national bank my name is dawn how can i help you today hi oh okay my name is jennifer brown and i need to check my account balance if i could [noise] [noise] [noise] [noise] what account would you like to check um [noise] uhm my savings account please [noise] [noise] oh but the way that you're doing one moment hello yeah one moment uh huh no problem [noise] your account balance is eighty two dollars is there anything else i can help you with no i don't think so thank you so much you were very helpful thank you have a good day bye bye [noise] you too
#
#             ### Task Type:
#             test_transcript =
#
# expected output:  check balance
# generated output: check balance
#
#  ----------------------

# %% [markdown]
# # Cleanup

# %%
deployed_llm.delete_model()
deployed_llm.delete_endpoint()
